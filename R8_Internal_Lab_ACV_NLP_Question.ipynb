# %% [markdown]
# # CV and Transfer Learning

# %% [markdown]
# Q1. Import tensorflow (2.x Mandatory)
#
# *   Import other required libraries

# %%
# %tensorflow_version 2.x
import tensorflow as tf
import numpy as np
# Out:
# TensorFlow 2.x selected.

# %%
tf.__version__
# Out:
# '2.1.0'

# %% [markdown]
# Q2. Load CIFAR10 dataset from keras and split into train and test
# *    Identify shape of x_train and y_train

# %%
(x_train, y_train),(x_test, y_test) = tf.keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step

# %% [markdown]
# Q3.
#
# *   Transform x_train and x_test on scale of 0-1
# *   Transform y_train and y_test to categories

# %%
x_train_tran = x_train/255
x_test_tran = x_test/255

# %%
y_train_tran = tf.keras.utils.to_categorical(y_train, num_classes=10)
y_test_tran = tf.keras.utils.to_categorical(y_test, num_classes=10)

# %% [markdown]
# Q4. Import necessary packages required for Model building
# *   Conv2D, Dense, Flatten, Dropout, MaxPooling2D etc.

# %%
#Clear any existing model in memory
tf.keras.backend.clear_session()

#Initialize model, reshape & normalize data
model = tf.keras.models.Sequential()

model.add(tf.keras.layers.BatchNormalization())

# %% [markdown]
# Q5. Prepare a CNN
#
# *   Which will include above layers
# *   Freely create your own Architecture and Arguments
# *   Print Model Summary

# %%
#Add first convolutional layer
model.add(tf.keras.layers.Conv2D(32, #Number of filters 
                                 kernel_size=(3,3), #Size of the filter
                                 activation='relu'))

#normalize data
model.add(tf.keras.layers.BatchNormalization())

#Add second convolutional layer
model.add(tf.keras.layers.Conv2D(64, kernel_size=(3,3), activation='relu'))

#normalize data
model.add(tf.keras.layers.BatchNormalization())

#Add MaxPooling layer
model.add(tf.keras.layers.MaxPool2D(pool_size=(2,2)))

#Flatten the output
model.add(tf.keras.layers.Flatten())

#Dense layer
model.add(tf.keras.layers.Dense(128, activation='relu'))

#Add another dropout layer
model.add(tf.keras.layers.Dropout(0.25))

#Output layer
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %% [markdown]
# Q6. Train the CNN
#
# *   Compile the model
# *   Fit the model (10 epochs, 32 batch size)
# *   Evaluate Model Performance

# %%
model.compile(optimizer='adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# %%
#Train the model
model.fit(x_train_tran,y_train_tran,          
          validation_data=(x_test_tran,y_test_tran),
          epochs=10,
          batch_size=32)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 19s 384us/sample - loss: 1.6367 - accuracy: 0.4177 - val_loss: 1.1952 - val_accuracy: 0.5750
# Epoch 2/10
# 50000/50000 [==============================] - 12s 244us/sample - loss: 1.2434 - accuracy: 0.5588 - val_loss: 1.0412 - val_accuracy: 0.6361
# Epoch 3/10
# 50000/50000 [==============================] - 12s 241us/sample - loss: 1.0928 - accuracy: 0.6152 - val_loss: 0.9918 - val_accuracy: 0.6688
# Epoch 4/10
# 50000/50000 [==============================] - 12s 241us/sample - loss: 0.9776 - accuracy: 0.6579 - val_loss: 0.9333 - val_accuracy: 0.6824
# Epoch 5/10
# 50000/50000 [==============================] - 12s 241us/sample - loss: 0.8814 - accuracy: 0.6904 - val_loss: 0.9519 - val_accuracy: 0.6780
# Epoch 6/10
# 50000/50000 [==============================] - 12s 241us/sample - loss: 0.7943 - accuracy: 0.7201 - val_loss: 1.0252 - val_accuracy: 0.6809
# Epoch 7/10
# 50000/50000 [==============================] - 12s 243us/sample - loss: 0.7175 - accuracy: 0.7454 - val_loss: 0.9282 - val_accuracy: 0.6950
# Epoch 8/10
# 50000/50000 [==============================] - 12s 244us/sample - loss: 0.6421 - accuracy: 0.7690 - val_loss: 0.9627 - val_accuracy: 0.6916
# Epoch 9/10
# 50000/50000 [==============================] - 12s 241us/sample - loss: 0.5890 - accuracy: 0.7913 - val_loss: 0.9826 - val_accuracy: 0.7065
# Epoch 10/10
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.5365 - accuracy: 0.8069 - val_loss: 1.0561 - val_accuracy: 0.6911

# %% [markdown]
# Q7. Import packages required for VGG16
#
# *   `tf.keras.application`
# > VGG16, preprocess_input, decode_predictions
# *   `tf.keras.preprocessing`
# > load_img, img_to_array

# %%
vgg = tf.keras.applications.vgg16.VGG16(include_top=True, #Should we include classification Layers
                                        weights='imagenet', #Load imagenet weights, 'None' will load random weights
                                        input_shape=(224,224,3)) #Input image size
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 11s 0us/step

# %% [markdown]
# Q8. Load image
#
#
# *   Mount Google Drive
# *   Navigate to image location (use `os`)
# *   Load image and assign a variable (use `load_img`)

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
image_path1 = "/content/drive/My Drive/49438170746_8378201627_c.jpg"
image_path2 = "/content/drive/My Drive/49436743043_2441587ab9_c.jpg"
image_path3 = "/content/drive/My Drive/49441887332_107afa786d_c.jpg"
image_path4 = "/content/drive/My Drive/4994221690_d070e8a355_c.jpg"

# %%
#Load and resize this image
img = tf.keras.preprocessing.image.load_img(image_path1)
load_img = img.resize((600,400))

# %% [markdown]
# Q9. Preprocess the image
#
#
# *   Convert image into array (use `img_to_array`)
# *   Check shape of image
# *   Reshape image into 4 dimensional format (use `reshape`)
# *   Prepare the image for VGG16 (Use `preprocess_input()`)

# %%
#Prepare Input 
#VGG takes 224x224 image
model_input = load_img.resize((224,224))
model_input = tf.keras.preprocessing.image.img_to_array(model_input)

#Image array should be normalized in same way as was done for VGG training
model_input = tf.keras.applications.vgg16.preprocess_input(model_input)

#Add a dimension to input data to make it a 4D input as required by model
model_input = np.expand_dims(model_input, axis=0)
model_input.shape
# Out:
# (1, 224, 224, 3)

# %% [markdown]
# Q10. Predict the Class of image
#
#
# *   Use `predict()` to calculate probabilities (Assign a variable)
# *   Convert the probabilities to class labels (Use `decode_predictions`)(Assign a variable)
# *   Print the classification results
#
#
# > Use
# >*  label = label[0][0]
# >*   print('%s (%.2f%%)' % (label[1], label[2]*100))
# >*(where label is variable assigned for `decode_predictions` )

# %%
#Predict
prediction = vgg.predict(model_input)
prediction.shape
# Out:
# (1, 1000)

# %%
np.argmax(prediction[0])
# Out:
# 565

# %%
tf.keras.applications.vgg16.decode_predictions(prediction)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 40960/35363 [==================================] - 0s 0us/step
# [[('n03393912', 'freight_car', 0.29296526),
#   ('n03160309', 'dam', 0.15731584),
#   ('n04467665', 'trailer_truck', 0.10562179),
#   ('n03272562', 'electric_locomotive', 0.1019811),
#   ('n03496892', 'harvester', 0.09259744)]]

# %% [markdown]
# #NLP

# %% [markdown]
# ## Question 1

# %% [markdown]
# Read file 'tweets.csv'

# %%
import pandas as pd
from pandas import read_csv

# %%
tweets = read_csv('/content/drive/My Drive/PGPAIML/31 Jan/Computer vision with CNN/Assignment/Internal Lab/tweets.csv',encoding = 'unicode_escape')

# %% [markdown]
# **Drop null values**
#
# *   Drop all the rows with null values

# %%
df = tweets.dropna()

# %% [markdown]
# **Print the dataframe**
# *   print initial 5 rows of the data

# %%
df.head()
# Out:
#                                           tweet_text  ... is_there_an_emotion_directed_at_a_brand_or_product
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs twe...  ...                                   Negative emotion
# 1  @jessedee Know about @fludapp ? Awesome iPad/i...  ...                                   Positive emotion
# 2  @swonderlin Can not wait for #iPad 2 also. The...  ...                                   Positive emotion
# 3  @sxsw I hope this year's festival isn't as cra...  ...                                   Negative emotion
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa M...  ...                                   Positive emotion
#
# [5 rows x 3 columns]

# %% [markdown]
# ##Question 2

# %% [markdown]
# **Preprocess data**
#
#
# *   convert all text to lowercase - use .lower()
# *   select only numbers, alphabets, and #+_ from text - use re.sub()
# *   strip all the text - use .strip() [To remove extra spaces]

# %%
import re
df = df.applymap(lambda s: s.lower())
df = df.applymap(lambda s: re.sub('[^0-9a-z #+_]','',s))
df = df.applymap(lambda s: s.strip())

# %% [markdown]
# ## Question 3

# %%
df.head()
# Out:
#                                           tweet_text  ... is_there_an_emotion_directed_at_a_brand_or_product
# 0  wesley83 i have a 3g iphone after 3 hrs tweeti...  ...                                   negative emotion
# 1  jessedee know about fludapp  awesome ipadiphon...  ...                                   positive emotion
# 2  swonderlin can not wait for #ipad 2 also they ...  ...                                   positive emotion
# 3  sxsw i hope this years festival isnt as crashy...  ...                                   negative emotion
# 4  sxtxstate great stuff on fri #sxsw marissa may...  ...                                   positive emotion
#
# [5 rows x 3 columns]

# %% [markdown]
# **Preprocess data**
#
#
# *   in column "is_there_an_emotion_directed_at_a_brand_or_product"
# select only those rows where value equal to "positive emotion" or "negative emotion"
# *   find the value counts of "positive emotion" and "negative emotion"

# %% [markdown]
# ##Question 4

# %%
df['is_there_an_emotion_directed_at_a_brand_or_product'].value_counts()
# Out:
# positive emotion                      2672
# negative emotion                       519
# no emotion toward brand or product      91
# i cant tell                              9
# Name: is_there_an_emotion_directed_at_a_brand_or_product, dtype: int64

# %%
df = df[(df['is_there_an_emotion_directed_at_a_brand_or_product']=='positive emotion') | (df['is_there_an_emotion_directed_at_a_brand_or_product']=='negative emotion')]

# %%
df['is_there_an_emotion_directed_at_a_brand_or_product'].value_counts()
# Out:
# positive emotion    2672
# negative emotion     519
# Name: is_there_an_emotion_directed_at_a_brand_or_product, dtype: int64

# %% [markdown]
# ### Encode labels
# - in column "is_there_an_emotion_directed_at_a_brand_or_product"
#     - change "positive emotion" to 1
#     - change "negative emotion" to 0
# - use map function to replace values

# %%
df['is_there_an_emotion_directed_at_a_brand_or_product'] = df.is_there_an_emotion_directed_at_a_brand_or_product.map({'positive emotion':1,'negative emotion':0})

# %%
df.head()
# Out:
#                                           tweet_text  ... is_there_an_emotion_directed_at_a_brand_or_product
# 0  wesley83 i have a 3g iphone after 3 hrs tweeti...  ...                                                  0
# 1  jessedee know about fludapp  awesome ipadiphon...  ...                                                  1
# 2  swonderlin can not wait for #ipad 2 also they ...  ...                                                  1
# 3  sxsw i hope this years festival isnt as crashy...  ...                                                  0
# 4  sxtxstate great stuff on fri #sxsw marissa may...  ...                                                  1
#
# [5 rows x 3 columns]

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Get feature and label
# - get column "tweet_text" as feature
# - get column "is_there_an_emotion_directed_at_a_brand_or_product" as label

# %%
feature = df['tweet_text']
label = df['is_there_an_emotion_directed_at_a_brand_or_product']

# %% [markdown]
# ### Create train and test data
# - use train_test_split to get train and test set
# - set a random_state
# - test_size: 0.25

# %%
from sklearn.model_selection import train_test_split
train_x,test_x,train_y,test_y=train_test_split(feature,label,test_size=.25,random_state=2)

# %% [markdown]
# ## Question 6
#
# ### Vectorize data
# - create document-term matrix
# - use CountVectorizer()
#     - ngram_range: (1, 2)
#     - stop_words: 'english'
#     - min_df: 2
# - do fit_transform on X_train
# - do transform on X_test

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
# use CountVectorizer to create document-term matrices from X_train and X_test
vect = CountVectorizer(ngram_range=(1,2),stop_words='english',min_df=2)
train_x_dtm = vect.fit_transform(train_x)
test_x_dtm = vect.transform(test_x)

# %% [markdown]
# ## Question 7
#
# ### Select classifier logistic regression
# - use logistic regression for predicting sentiment of the given tweet
# - initialize classifier

# %%
from sklearn.linear_model import LogisticRegression
lgr = LogisticRegression()

# %% [markdown]
# ### Fit the classifer
# - fit logistic regression classifier

# %%
lgr.fit(train_x_dtm, train_y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# ## Question 8
#
# ### Select classifier naive bayes
# - use naive bayes for predicting sentiment of the given tweet
# - initialize classifier
# - use MultinomialNB

# %%
from sklearn.naive_bayes import MultinomialNB
# use Naive Bayes to predict the star rating
nb = MultinomialNB()

# %% [markdown]
# ### Fit the classifer
# - fit naive bayes classifier

# %%
nb.fit(train_x_dtm, train_y)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %% [markdown]
# ## Question 9
#
# ### Make predictions on logistic regression
# - use your trained logistic regression model to make predictions on X_test

# %%
from sklearn import metrics
# %matplotlib inline
y_pred_class_lgr = lgr.predict(test_x_dtm)

# %% [markdown]
# ### Make predictions on naive bayes
# - use your trained naive bayes model to make predictions on X_test
# - use a different variable name to store predictions so that they are kept separately

# %%
y_pred_class_nb = nb.predict(test_x_dtm)

# %% [markdown]
# ## Question 10
#
# ### Calculate accuracy of logistic regression
# - check accuracy of logistic regression classifer
# - use sklearn.metrics.accuracy_score

# %%
# calculate accuracy
print (metrics.accuracy_score(test_y, y_pred_class_lgr))
# Out:
# 0.8734335839598998

# %% [markdown]
# ### Calculate accuracy of naive bayes
# - check accuracy of naive bayes classifer
# - use sklearn.metrics.accuracy_score

# %%
# calculate accuracy
print (metrics.accuracy_score(test_y, y_pred_class_nb))
# Out:
# 0.8609022556390977
