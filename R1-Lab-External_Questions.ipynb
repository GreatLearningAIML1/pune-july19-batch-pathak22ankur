# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
import pandas as pd 
Iris= pd.read_csv("Iris.csv")

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
Iris.dtypes
# Out:
# Sepal Length (in cm)    float64
# Sepal Width in (cm)     float64
# Petal length (in cm)    float64
# Petal width (in cm)     float64
# Class                    object
# dtype: object

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
Iris.head(10)
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  Petal width (in cm)        Class
# 0                   5.1                  3.5                   1.4                  0.2  Iris-setosa
# 1                   4.9                  3.0                   1.4                  0.2  Iris-setosa
# 2                   4.7                  3.2                   1.3                  0.2  Iris-setosa
# 3                   4.6                  3.1                   1.5                  0.2  Iris-setosa
# 4                   5.0                  3.6                   1.4                  0.2  Iris-setosa
# 5                   5.4                  3.9                   1.7                  0.4  Iris-setosa
# 6                   4.6                  3.4                   1.4                  0.3  Iris-setosa
# 7                   5.0                  3.4                   1.5                  0.2  Iris-setosa
# 8                   4.4                  2.9                   1.4                  0.2  Iris-setosa
# 9                   4.9                  3.1                   1.5                  0.1  Iris-setosa

# %%
Iris.tail(10)
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  Petal width (in cm)           Class
# 140                   6.7                  3.1                   5.6                  2.4  Iris-virginica
# 141                   6.9                  3.1                   5.1                  2.3  Iris-virginica
# 142                   5.8                  2.7                   5.1                  1.9  Iris-virginica
# 143                   6.8                  3.2                   5.9                  2.3  Iris-virginica
# 144                   6.7                  3.3                   5.7                  2.5  Iris-virginica
# 145                   6.7                  3.0                   5.2                  2.3  Iris-virginica
# 146                   6.3                  2.5                   5.0                  1.9  Iris-virginica
# 147                   6.5                  3.0                   5.2                  2.0  Iris-virginica
# 148                   6.2                  3.4                   5.4                  2.3  Iris-virginica
# 149                   5.9                  3.0                   5.1                  1.8  Iris-virginica

# %% [markdown]
# ### Find the shape of the dataset

# %%
Iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
Iris.set_index("Sepal Length (in cm)", inplace = False)
# Out:
#                       Sepal Width in (cm)  Petal length (in cm)  Petal width (in cm)           Class
# Sepal Length (in cm)
# 5.1                                   3.5                   1.4                  0.2     Iris-setosa
# 4.9                                   3.0                   1.4                  0.2     Iris-setosa
# 4.7                                   3.2                   1.3                  0.2     Iris-setosa
# 4.6                                   3.1                   1.5                  0.2     Iris-setosa
# 5.0                                   3.6                   1.4                  0.2     Iris-setosa
# 5.4                                   3.9                   1.7                  0.4     Iris-setosa
# 4.6                                   3.4                   1.4                  0.3     Iris-setosa
# 5.0                                   3.4                   1.5                  0.2     Iris-setosa
# 4.4                                   2.9                   1.4                  0.2     Iris-setosa
# 4.9                                   3.1                   1.5                  0.1     Iris-setosa
# 5.4                                   3.7                   1.5                  0.2     Iris-setosa
# 4.8                                   3.4                   1.6                  0.2     Iris-setosa
# 4.8                                   3.0                   1.4                  0.1     Iris-setosa
# 4.3                                   3.0                   1.1                  0.1     Iris-setosa
# 5.8                                   4.0                   1.2                  0.2     Iris-setosa
# 5.7                                   4.4                   1.5                  0.4     Iris-setosa
# 5.4                                   3.9                   1.3                  0.4     Iris-setosa
# 5.1                                   3.5                   1.4                  0.3     Iris-setosa
# 5.7                                   3.8                   1.7                  0.3     Iris-setosa
# 5.1                                   3.8                   1.5                  0.3     Iris-setosa
# 5.4                                   3.4                   1.7                  0.2     Iris-setosa
# 5.1                                   3.7                   1.5                  0.4     Iris-setosa
# 4.6                                   3.6                   1.0                  0.2     Iris-setosa
# 5.1                                   3.3                   1.7                  0.5     Iris-setosa
# 4.8                                   3.4                   1.9                  0.2     Iris-setosa
# 5.0                                   3.0                   1.6                  0.2     Iris-setosa
# 5.0                                   3.4                   1.6                  0.4     Iris-setosa
# 5.2                                   3.5                   1.5                  0.2     Iris-setosa
# 5.2                                   3.4                   1.4                  0.2     Iris-setosa
# 4.7                                   3.2                   1.6                  0.2     Iris-setosa
# ...                                   ...                   ...                  ...             ...
# 6.9                                   3.2                   5.7                  2.3  Iris-virginica
# 5.6                                   2.8                   4.9                  2.0  Iris-virginica
# 7.7                                   2.8                   6.7                  2.0  Iris-virginica
# 6.3                                   2.7                   4.9                  1.8  Iris-virginica
# 6.7                                   3.3                   5.7                  2.1  Iris-virginica
# 7.2                                   3.2                   6.0                  1.8  Iris-virginica
# 6.2                                   2.8                   4.8                  1.8  Iris-virginica
# 6.1                                   3.0                   4.9                  1.8  Iris-virginica
# 6.4                                   2.8                   5.6                  2.1  Iris-virginica
# 7.2                                   3.0                   5.8                  1.6  Iris-virginica
# 7.4                                   2.8                   6.1                  1.9  Iris-virginica
# 7.9                                   3.8                   6.4                  2.0  Iris-virginica
# 6.4                                   2.8                   5.6                  2.2  Iris-virginica
# 6.3                                   2.8                   5.1                  1.5  Iris-virginica
# 6.1                                   2.6                   5.6                  1.4  Iris-virginica
# 7.7                                   3.0                   6.1                  2.3  Iris-virginica
# 6.3                                   3.4                   5.6                  2.4  Iris-virginica
# 6.4                                   3.1                   5.5                  1.8  Iris-virginica
# 6.0                                   3.0                   4.8                  1.8  Iris-virginica
# 6.9                                   3.1                   5.4                  2.1  Iris-virginica
# 6.7                                   3.1                   5.6                  2.4  Iris-virginica
# 6.9                                   3.1                   5.1                  2.3  Iris-virginica
# 5.8                                   2.7                   5.1                  1.9  Iris-virginica
# 6.8                                   3.2                   5.9                  2.3  Iris-virginica
# 6.7                                   3.3                   5.7                  2.5  Iris-virginica
# 6.7                                   3.0                   5.2                  2.3  Iris-virginica
# 6.3                                   2.5                   5.0                  1.9  Iris-virginica
# 6.5                                   3.0                   5.2                  2.0  Iris-virginica
# 6.2                                   3.4                   5.4                  2.3  Iris-virginica
# 5.9                                   3.0                   5.1                  1.8  Iris-virginica
#
# [150 rows x 4 columns]

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
Iris.iloc[:,2]
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
# 5      1.7
# 6      1.4
# 7      1.5
# 8      1.4
# 9      1.5
# 10     1.5
# 11     1.6
# 12     1.4
# 13     1.1
# 14     1.2
# 15     1.5
# 16     1.3
# 17     1.4
# 18     1.7
# 19     1.5
# 20     1.7
# 21     1.5
# 22     1.0
# 23     1.7
# 24     1.9
# 25     1.6
# 26     1.6
# 27     1.5
# 28     1.4
# 29     1.6
#       ...
# 120    5.7
# 121    4.9
# 122    6.7
# 123    4.9
# 124    5.7
# 125    6.0
# 126    4.8
# 127    4.9
# 128    5.6
# 129    5.8
# 130    6.1
# 131    6.4
# 132    5.6
# 133    5.1
# 134    5.6
# 135    6.1
# 136    5.6
# 137    5.5
# 138    4.8
# 139    5.4
# 140    5.6
# 141    5.1
# 142    5.1
# 143    5.9
# 144    5.7
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: Petal length (in cm), Length: 150, dtype: float64

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
Iris.loc[:,"Sepal Length (in cm)":"Sepal Width in (cm)"].head(10)
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)
# 0                   5.1                  3.5
# 1                   4.9                  3.0
# 2                   4.7                  3.2
# 3                   4.6                  3.1
# 4                   5.0                  3.6
# 5                   5.4                  3.9
# 6                   4.6                  3.4
# 7                   5.0                  3.4
# 8                   4.4                  2.9
# 9                   4.9                  3.1

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
Iris.loc[Iris['Class']=='Iris-setosa']
# Out:
#     Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  Petal width (in cm)        Class
# 0                    5.1                  3.5                   1.4                  0.2  Iris-setosa
# 1                    4.9                  3.0                   1.4                  0.2  Iris-setosa
# 2                    4.7                  3.2                   1.3                  0.2  Iris-setosa
# 3                    4.6                  3.1                   1.5                  0.2  Iris-setosa
# 4                    5.0                  3.6                   1.4                  0.2  Iris-setosa
# 5                    5.4                  3.9                   1.7                  0.4  Iris-setosa
# 6                    4.6                  3.4                   1.4                  0.3  Iris-setosa
# 7                    5.0                  3.4                   1.5                  0.2  Iris-setosa
# 8                    4.4                  2.9                   1.4                  0.2  Iris-setosa
# 9                    4.9                  3.1                   1.5                  0.1  Iris-setosa
# 10                   5.4                  3.7                   1.5                  0.2  Iris-setosa
# 11                   4.8                  3.4                   1.6                  0.2  Iris-setosa
# 12                   4.8                  3.0                   1.4                  0.1  Iris-setosa
# 13                   4.3                  3.0                   1.1                  0.1  Iris-setosa
# 14                   5.8                  4.0                   1.2                  0.2  Iris-setosa
# 15                   5.7                  4.4                   1.5                  0.4  Iris-setosa
# 16                   5.4                  3.9                   1.3                  0.4  Iris-setosa
# 17                   5.1                  3.5                   1.4                  0.3  Iris-setosa
# 18                   5.7                  3.8                   1.7                  0.3  Iris-setosa
# 19                   5.1                  3.8                   1.5                  0.3  Iris-setosa
# 20                   5.4                  3.4                   1.7                  0.2  Iris-setosa
# 21                   5.1                  3.7                   1.5                  0.4  Iris-setosa
# 22                   4.6                  3.6                   1.0                  0.2  Iris-setosa
# 23                   5.1                  3.3                   1.7                  0.5  Iris-setosa
# 24                   4.8                  3.4                   1.9                  0.2  Iris-setosa
# 25                   5.0                  3.0                   1.6                  0.2  Iris-setosa
# 26                   5.0                  3.4                   1.6                  0.4  Iris-setosa
# 27                   5.2                  3.5                   1.5                  0.2  Iris-setosa
# 28                   5.2                  3.4                   1.4                  0.2  Iris-setosa
# 29                   4.7                  3.2                   1.6                  0.2  Iris-setosa
# 30                   4.8                  3.1                   1.6                  0.2  Iris-setosa
# 31                   5.4                  3.4                   1.5                  0.4  Iris-setosa
# 32                   5.2                  4.1                   1.5                  0.1  Iris-setosa
# 33                   5.5                  4.2                   1.4                  0.2  Iris-setosa
# 34                   4.9                  3.1                   1.5                  0.1  Iris-setosa
# 35                   5.0                  3.2                   1.2                  0.2  Iris-setosa
# 36                   5.5                  3.5                   1.3                  0.2  Iris-setosa
# 37                   4.9                  3.1                   1.5                  0.1  Iris-setosa
# 38                   4.4                  3.0                   1.3                  0.2  Iris-setosa
# 39                   5.1                  3.4                   1.5                  0.2  Iris-setosa
# 40                   5.0                  3.5                   1.3                  0.3  Iris-setosa
# 41                   4.5                  2.3                   1.3                  0.3  Iris-setosa
# 42                   4.4                  3.2                   1.3                  0.2  Iris-setosa
# 43                   5.0                  3.5                   1.6                  0.6  Iris-setosa
# 44                   5.1                  3.8                   1.9                  0.4  Iris-setosa
# 45                   4.8                  3.0                   1.4                  0.3  Iris-setosa
# 46                   5.1                  3.8                   1.6                  0.2  Iris-setosa
# 47                   4.6                  3.2                   1.4                  0.2  Iris-setosa
# 48                   5.3                  3.7                   1.5                  0.2  Iris-setosa
# 49                   5.0                  3.3                   1.4                  0.2  Iris-setosa

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
Iris.insert(2,"SepalExtra",(Iris['Sepal Length (in cm)'] ) * (Iris['Sepal Width in (cm)']),True)

# %%
Iris
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  SepalExtra  Petal length (in cm)  Petal width (in cm)           Class
# 0                     5.1                  3.5       17.85                   1.4                  0.2     Iris-setosa
# 1                     4.9                  3.0       14.70                   1.4                  0.2     Iris-setosa
# 2                     4.7                  3.2       15.04                   1.3                  0.2     Iris-setosa
# 3                     4.6                  3.1       14.26                   1.5                  0.2     Iris-setosa
# 4                     5.0                  3.6       18.00                   1.4                  0.2     Iris-setosa
# 5                     5.4                  3.9       21.06                   1.7                  0.4     Iris-setosa
# 6                     4.6                  3.4       15.64                   1.4                  0.3     Iris-setosa
# 7                     5.0                  3.4       17.00                   1.5                  0.2     Iris-setosa
# 8                     4.4                  2.9       12.76                   1.4                  0.2     Iris-setosa
# 9                     4.9                  3.1       15.19                   1.5                  0.1     Iris-setosa
# 10                    5.4                  3.7       19.98                   1.5                  0.2     Iris-setosa
# 11                    4.8                  3.4       16.32                   1.6                  0.2     Iris-setosa
# 12                    4.8                  3.0       14.40                   1.4                  0.1     Iris-setosa
# 13                    4.3                  3.0       12.90                   1.1                  0.1     Iris-setosa
# 14                    5.8                  4.0       23.20                   1.2                  0.2     Iris-setosa
# 15                    5.7                  4.4       25.08                   1.5                  0.4     Iris-setosa
# 16                    5.4                  3.9       21.06                   1.3                  0.4     Iris-setosa
# 17                    5.1                  3.5       17.85                   1.4                  0.3     Iris-setosa
# 18                    5.7                  3.8       21.66                   1.7                  0.3     Iris-setosa
# 19                    5.1                  3.8       19.38                   1.5                  0.3     Iris-setosa
# 20                    5.4                  3.4       18.36                   1.7                  0.2     Iris-setosa
# 21                    5.1                  3.7       18.87                   1.5                  0.4     Iris-setosa
# 22                    4.6                  3.6       16.56                   1.0                  0.2     Iris-setosa
# 23                    5.1                  3.3       16.83                   1.7                  0.5     Iris-setosa
# 24                    4.8                  3.4       16.32                   1.9                  0.2     Iris-setosa
# 25                    5.0                  3.0       15.00                   1.6                  0.2     Iris-setosa
# 26                    5.0                  3.4       17.00                   1.6                  0.4     Iris-setosa
# 27                    5.2                  3.5       18.20                   1.5                  0.2     Iris-setosa
# 28                    5.2                  3.4       17.68                   1.4                  0.2     Iris-setosa
# 29                    4.7                  3.2       15.04                   1.6                  0.2     Iris-setosa
# ..                    ...                  ...         ...                   ...                  ...             ...
# 120                   6.9                  3.2       22.08                   5.7                  2.3  Iris-virginica
# 121                   5.6                  2.8       15.68                   4.9                  2.0  Iris-virginica
# 122                   7.7                  2.8       21.56                   6.7                  2.0  Iris-virginica
# 123                   6.3                  2.7       17.01                   4.9                  1.8  Iris-virginica
# 124                   6.7                  3.3       22.11                   5.7                  2.1  Iris-virginica
# 125                   7.2                  3.2       23.04                   6.0                  1.8  Iris-virginica
# 126                   6.2                  2.8       17.36                   4.8                  1.8  Iris-virginica
# 127                   6.1                  3.0       18.30                   4.9                  1.8  Iris-virginica
# 128                   6.4                  2.8       17.92                   5.6                  2.1  Iris-virginica
# 129                   7.2                  3.0       21.60                   5.8                  1.6  Iris-virginica
# 130                   7.4                  2.8       20.72                   6.1                  1.9  Iris-virginica
# 131                   7.9                  3.8       30.02                   6.4                  2.0  Iris-virginica
# 132                   6.4                  2.8       17.92                   5.6                  2.2  Iris-virginica
# 133                   6.3                  2.8       17.64                   5.1                  1.5  Iris-virginica
# 134                   6.1                  2.6       15.86                   5.6                  1.4  Iris-virginica
# 135                   7.7                  3.0       23.10                   6.1                  2.3  Iris-virginica
# 136                   6.3                  3.4       21.42                   5.6                  2.4  Iris-virginica
# 137                   6.4                  3.1       19.84                   5.5                  1.8  Iris-virginica
# 138                   6.0                  3.0       18.00                   4.8                  1.8  Iris-virginica
# 139                   6.9                  3.1       21.39                   5.4                  2.1  Iris-virginica
# 140                   6.7                  3.1       20.77                   5.6                  2.4  Iris-virginica
# 141                   6.9                  3.1       21.39                   5.1                  2.3  Iris-virginica
# 142                   5.8                  2.7       15.66                   5.1                  1.9  Iris-virginica
# 143                   6.8                  3.2       21.76                   5.9                  2.3  Iris-virginica
# 144                   6.7                  3.3       22.11                   5.7                  2.5  Iris-virginica
# 145                   6.7                  3.0       20.10                   5.2                  2.3  Iris-virginica
# 146                   6.3                  2.5       15.75                   5.0                  1.9  Iris-virginica
# 147                   6.5                  3.0       19.50                   5.2                  2.0  Iris-virginica
# 148                   6.2                  3.4       21.08                   5.4                  2.3  Iris-virginica
# 149                   5.9                  3.0       17.70                   5.1                  1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
Iris.mean()
# Out:
# Sepal Length (in cm)     5.843333
# Sepal Width in (cm)      3.054000
# SepalExtra              17.806533
# Petal length (in cm)     3.758667
# Petal width (in cm)      1.198667
# dtype: float64

# %%
import numpy as np
np.var(Iris)
# Out:
# Sepal Length (in cm)     0.681122
# Sepal Width in (cm)      0.186751
# SepalExtra              11.272436
# Petal length (in cm)     3.092425
# Petal width (in cm)      0.578532
# dtype: float64

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
def print_number(arg1,arg2):
    print ("1st number : ", arg1)
    print ("2nd number : ", arg2)

# %%
num1=Iris.loc[4,"Sepal Length (in cm)"]
num2=Iris.loc[4,"Sepal Width in (cm)"]
print_number(num1,num2)
# Out:
# 1st number :  5.0
# 2nd number :  3.6

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
sepal_length_range = (Iris["Sepal Length (in cm)"].max())-(Iris["Sepal Length (in cm)"].min())
sepal_length_range
# Out:
# 3.6000000000000005

# %%
sepal_width_range = (Iris["Sepal Width in (cm)"].max())-(Iris["Sepal Width in (cm)"].min())
sepal_width_range
# Out:
# 2.4000000000000004

# %%
sepal_extra_range = (Iris["SepalExtra"].max())-(Iris["SepalExtra"].min())
sepal_extra_range
# Out:
# 20.02

# %%
petal_length_range = (Iris["Petal length (in cm)"].max())-(Iris["Petal length (in cm)"].min())
petal_length_range
# Out:
# 5.9

# %%
petal_width_range = (Iris["Petal width (in cm)"].max())-(Iris["Petal width (in cm)"].min())
petal_width_range
# Out:
# 2.4

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
Iris.sort_values("Petal width (in cm)",0,True,False)
Iris
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  SepalExtra  Petal length (in cm)  Petal width (in cm)           Class
# 0                     5.1                  3.5       17.85                   1.4                  0.2     Iris-setosa
# 1                     4.9                  3.0       14.70                   1.4                  0.2     Iris-setosa
# 2                     4.7                  3.2       15.04                   1.3                  0.2     Iris-setosa
# 3                     4.6                  3.1       14.26                   1.5                  0.2     Iris-setosa
# 4                     5.0                  3.6       18.00                   1.4                  0.2     Iris-setosa
# 5                     5.4                  3.9       21.06                   1.7                  0.4     Iris-setosa
# 6                     4.6                  3.4       15.64                   1.4                  0.3     Iris-setosa
# 7                     5.0                  3.4       17.00                   1.5                  0.2     Iris-setosa
# 8                     4.4                  2.9       12.76                   1.4                  0.2     Iris-setosa
# 9                     4.9                  3.1       15.19                   1.5                  0.1     Iris-setosa
# 10                    5.4                  3.7       19.98                   1.5                  0.2     Iris-setosa
# 11                    4.8                  3.4       16.32                   1.6                  0.2     Iris-setosa
# 12                    4.8                  3.0       14.40                   1.4                  0.1     Iris-setosa
# 13                    4.3                  3.0       12.90                   1.1                  0.1     Iris-setosa
# 14                    5.8                  4.0       23.20                   1.2                  0.2     Iris-setosa
# 15                    5.7                  4.4       25.08                   1.5                  0.4     Iris-setosa
# 16                    5.4                  3.9       21.06                   1.3                  0.4     Iris-setosa
# 17                    5.1                  3.5       17.85                   1.4                  0.3     Iris-setosa
# 18                    5.7                  3.8       21.66                   1.7                  0.3     Iris-setosa
# 19                    5.1                  3.8       19.38                   1.5                  0.3     Iris-setosa
# 20                    5.4                  3.4       18.36                   1.7                  0.2     Iris-setosa
# 21                    5.1                  3.7       18.87                   1.5                  0.4     Iris-setosa
# 22                    4.6                  3.6       16.56                   1.0                  0.2     Iris-setosa
# 23                    5.1                  3.3       16.83                   1.7                  0.5     Iris-setosa
# 24                    4.8                  3.4       16.32                   1.9                  0.2     Iris-setosa
# 25                    5.0                  3.0       15.00                   1.6                  0.2     Iris-setosa
# 26                    5.0                  3.4       17.00                   1.6                  0.4     Iris-setosa
# 27                    5.2                  3.5       18.20                   1.5                  0.2     Iris-setosa
# 28                    5.2                  3.4       17.68                   1.4                  0.2     Iris-setosa
# 29                    4.7                  3.2       15.04                   1.6                  0.2     Iris-setosa
# ..                    ...                  ...         ...                   ...                  ...             ...
# 120                   6.9                  3.2       22.08                   5.7                  2.3  Iris-virginica
# 121                   5.6                  2.8       15.68                   4.9                  2.0  Iris-virginica
# 122                   7.7                  2.8       21.56                   6.7                  2.0  Iris-virginica
# 123                   6.3                  2.7       17.01                   4.9                  1.8  Iris-virginica
# 124                   6.7                  3.3       22.11                   5.7                  2.1  Iris-virginica
# 125                   7.2                  3.2       23.04                   6.0                  1.8  Iris-virginica
# 126                   6.2                  2.8       17.36                   4.8                  1.8  Iris-virginica
# 127                   6.1                  3.0       18.30                   4.9                  1.8  Iris-virginica
# 128                   6.4                  2.8       17.92                   5.6                  2.1  Iris-virginica
# 129                   7.2                  3.0       21.60                   5.8                  1.6  Iris-virginica
# 130                   7.4                  2.8       20.72                   6.1                  1.9  Iris-virginica
# 131                   7.9                  3.8       30.02                   6.4                  2.0  Iris-virginica
# 132                   6.4                  2.8       17.92                   5.6                  2.2  Iris-virginica
# 133                   6.3                  2.8       17.64                   5.1                  1.5  Iris-virginica
# 134                   6.1                  2.6       15.86                   5.6                  1.4  Iris-virginica
# 135                   7.7                  3.0       23.10                   6.1                  2.3  Iris-virginica
# 136                   6.3                  3.4       21.42                   5.6                  2.4  Iris-virginica
# 137                   6.4                  3.1       19.84                   5.5                  1.8  Iris-virginica
# 138                   6.0                  3.0       18.00                   4.8                  1.8  Iris-virginica
# 139                   6.9                  3.1       21.39                   5.4                  2.1  Iris-virginica
# 140                   6.7                  3.1       20.77                   5.6                  2.4  Iris-virginica
# 141                   6.9                  3.1       21.39                   5.1                  2.3  Iris-virginica
# 142                   5.8                  2.7       15.66                   5.1                  1.9  Iris-virginica
# 143                   6.8                  3.2       21.76                   5.9                  2.3  Iris-virginica
# 144                   6.7                  3.3       22.11                   5.7                  2.5  Iris-virginica
# 145                   6.7                  3.0       20.10                   5.2                  2.3  Iris-virginica
# 146                   6.3                  2.5       15.75                   5.0                  1.9  Iris-virginica
# 147                   6.5                  3.0       19.50                   5.2                  2.0  Iris-virginica
# 148                   6.2                  3.4       21.08                   5.4                  2.3  Iris-virginica
# 149                   5.9                  3.0       17.70                   5.1                  1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
Iris.drop("SepalExtra",axis=1,index=None,columns=None,level=None,inplace=True)
Iris
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  Petal width (in cm)           Class
# 0                     5.1                  3.5                   1.4                  0.2     Iris-setosa
# 1                     4.9                  3.0                   1.4                  0.2     Iris-setosa
# 2                     4.7                  3.2                   1.3                  0.2     Iris-setosa
# 3                     4.6                  3.1                   1.5                  0.2     Iris-setosa
# 4                     5.0                  3.6                   1.4                  0.2     Iris-setosa
# 5                     5.4                  3.9                   1.7                  0.4     Iris-setosa
# 6                     4.6                  3.4                   1.4                  0.3     Iris-setosa
# 7                     5.0                  3.4                   1.5                  0.2     Iris-setosa
# 8                     4.4                  2.9                   1.4                  0.2     Iris-setosa
# 9                     4.9                  3.1                   1.5                  0.1     Iris-setosa
# 10                    5.4                  3.7                   1.5                  0.2     Iris-setosa
# 11                    4.8                  3.4                   1.6                  0.2     Iris-setosa
# 12                    4.8                  3.0                   1.4                  0.1     Iris-setosa
# 13                    4.3                  3.0                   1.1                  0.1     Iris-setosa
# 14                    5.8                  4.0                   1.2                  0.2     Iris-setosa
# 15                    5.7                  4.4                   1.5                  0.4     Iris-setosa
# 16                    5.4                  3.9                   1.3                  0.4     Iris-setosa
# 17                    5.1                  3.5                   1.4                  0.3     Iris-setosa
# 18                    5.7                  3.8                   1.7                  0.3     Iris-setosa
# 19                    5.1                  3.8                   1.5                  0.3     Iris-setosa
# 20                    5.4                  3.4                   1.7                  0.2     Iris-setosa
# 21                    5.1                  3.7                   1.5                  0.4     Iris-setosa
# 22                    4.6                  3.6                   1.0                  0.2     Iris-setosa
# 23                    5.1                  3.3                   1.7                  0.5     Iris-setosa
# 24                    4.8                  3.4                   1.9                  0.2     Iris-setosa
# 25                    5.0                  3.0                   1.6                  0.2     Iris-setosa
# 26                    5.0                  3.4                   1.6                  0.4     Iris-setosa
# 27                    5.2                  3.5                   1.5                  0.2     Iris-setosa
# 28                    5.2                  3.4                   1.4                  0.2     Iris-setosa
# 29                    4.7                  3.2                   1.6                  0.2     Iris-setosa
# ..                    ...                  ...                   ...                  ...             ...
# 120                   6.9                  3.2                   5.7                  2.3  Iris-virginica
# 121                   5.6                  2.8                   4.9                  2.0  Iris-virginica
# 122                   7.7                  2.8                   6.7                  2.0  Iris-virginica
# 123                   6.3                  2.7                   4.9                  1.8  Iris-virginica
# 124                   6.7                  3.3                   5.7                  2.1  Iris-virginica
# 125                   7.2                  3.2                   6.0                  1.8  Iris-virginica
# 126                   6.2                  2.8                   4.8                  1.8  Iris-virginica
# 127                   6.1                  3.0                   4.9                  1.8  Iris-virginica
# 128                   6.4                  2.8                   5.6                  2.1  Iris-virginica
# 129                   7.2                  3.0                   5.8                  1.6  Iris-virginica
# 130                   7.4                  2.8                   6.1                  1.9  Iris-virginica
# 131                   7.9                  3.8                   6.4                  2.0  Iris-virginica
# 132                   6.4                  2.8                   5.6                  2.2  Iris-virginica
# 133                   6.3                  2.8                   5.1                  1.5  Iris-virginica
# 134                   6.1                  2.6                   5.6                  1.4  Iris-virginica
# 135                   7.7                  3.0                   6.1                  2.3  Iris-virginica
# 136                   6.3                  3.4                   5.6                  2.4  Iris-virginica
# 137                   6.4                  3.1                   5.5                  1.8  Iris-virginica
# 138                   6.0                  3.0                   4.8                  1.8  Iris-virginica
# 139                   6.9                  3.1                   5.4                  2.1  Iris-virginica
# 140                   6.7                  3.1                   5.6                  2.4  Iris-virginica
# 141                   6.9                  3.1                   5.1                  2.3  Iris-virginica
# 142                   5.8                  2.7                   5.1                  1.9  Iris-virginica
# 143                   6.8                  3.2                   5.9                  2.3  Iris-virginica
# 144                   6.7                  3.3                   5.7                  2.5  Iris-virginica
# 145                   6.7                  3.0                   5.2                  2.3  Iris-virginica
# 146                   6.3                  2.5                   5.0                  1.9  Iris-virginica
# 147                   6.5                  3.0                   5.2                  2.0  Iris-virginica
# 148                   6.2                  3.4                   5.4                  2.3  Iris-virginica
# 149                   5.9                  3.0                   5.1                  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
IrisSubset = Iris.iloc[:,:3].head(10)

# %%
IrisSubset
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
hrinfo = pd.read_csv("HR_external.txt", sep='\t')
hrinfo.head()
# Out:
#   Individual  Attrition  Age  ...  YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0        Ind1       Yes   41  ...                   4                        0                     5
# 1        Ind2        No   49  ...                   7                        1                     7
# 2        Ind3       Yes   37  ...                   0                        0                     0
# 3        Ind4        No   33  ...                   7                        3                     0
# 4        Ind5        No   27  ...                   2                        2                     2
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
hrinfo.shape
# Out:
# (1470, 35)

# %%
len(hrinfo.index)
# Out:
# 1470

# %%
len(hrinfo.columns)
# Out:
# 35

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
hrinfo.dtypes
# Out:
# Individual                  object
# Attrition                   object
# Age                          int64
# BusinessTravel               int64
# DailyRate                    int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                       int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                      int64
# JobSatisfaction              int64
# MaritalStatus                int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                     int64
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
hrinfo.iloc[:,2:9]
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  EducationField
# 0      41               1       1102           1                 1          2               1
# 1      49               2        279           2                 8          1               1
# 2      37               1       1373           2                 2          2               6
# 3      33               2       1392           2                 3          4               1
# 4      27               1        591           2                 2          1               2
# 5      32               2       1005           2                 2          2               1
# 6      59               1       1324           2                 3          3               2
# 7      30               1       1358           2                24          1               1
# 8      38               2        216           2                23          3               1
# 9      36               1       1299           2                27          3               2
# 10     35               1        809           2                16          3               2
# 11     29               1        153           2                15          2               1
# 12     31               1        670           2                26          1               1
# 13     34               1       1346           2                19          2               2
# 14     28               1        103           2                24          3               1
# 15     29               1       1389           2                21          4               1
# 16     32               1        334           2                 5          2               1
# 17     22               3       1123           2                16          2               2
# 18     53               1       1219           1                 2          4               1
# 19     38               1        371           2                 2          3               1
# 20     24               3        673           2                11          2               6
# 21     36               1       1218           1                 9          4               1
# 22     34               1        419           2                 7          4               1
# 23     21               1        391           2                15          2               1
# 24     34               1        699           2                 6          1               2
# 25     53               1       1282           2                 5          3               6
# 26     32               2       1125           2                16          1               1
# 27     42               1        691           1                 8          4               3
# 28     44               1        477           2                 7          4               2
# 29     46               1        705           1                 2          4               3
# ...   ...             ...        ...         ...               ...        ...             ...
# 1440   36               2        688           2                 4          2               1
# 1441   56               3        667           2                 1          4               1
# 1442   29               1       1092           2                 1          4               2
# 1443   42               1        300           2                 2          3               1
# 1444   56               1        310           2                 7          2               4
# 1445   41               1        582           2                28          4               1
# 1446   34               1        704           1                28          3               3
# 1447   36               3        301           1                15          4               3
# 1448   41               1        930           1                 3          3               1
# 1449   32               1        529           2                 2          3               4
# 1450   35               1       1146           3                26          4               1
# 1451   38               1        345           1                10          2               1
# 1452   50               2        878           1                 1          4               1
# 1453   36               1       1120           1                11          4               3
# 1454   45               1        374           1                20          3               1
# 1455   40               1       1322           2                 2          4               1
# 1456   35               2       1199           2                18          4               1
# 1457   40               1       1194           2                 2          4               2
# 1458   35               1        287           2                 1          4               1
# 1459   29               1       1378           2                13          2               6
# 1460   29               1        468           2                28          4               2
# 1461   50               1        410           1                28          3               3
# 1462   39               1        722           1                24          1               3
# 1463   31               3        325           2                 5          3               2
# 1464   26               1       1167           1                 5          3               6
# 1465   36               2        884           2                23          2               2
# 1466   39               1        613           2                 6          1               2
# 1467   27               1        155           2                 4          3               1
# 1468   49               2       1023           1                 2          3               2
# 1469   34               1        628           2                 8          3               2
#
# [1470 rows x 7 columns]

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
male_count=0
female_count=0
for gender in hrinfo.loc[:,'Gender']:
    if gender == 1 :
        male_count+=1
    else:
        female_count+=1
        

print("Male count = ",male_count)
print("Female count = ",female_count)
# Out:
# Male count =  882
# Female count =  588

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
q1= np.quantile(hrinfo.loc[:,'Age'],0.25)
q3= np.quantile(hrinfo.loc[:,'Age'],0.75)
print("IQR is : " , q3-q1)
# Out:
# IQR is :  13.0

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %%
dailyrate_mean = np.mean(hrinfo.loc[:,'DailyRate'])
dailyrate_median = np.median(hrinfo.loc[:,'DailyRate'])
dailyrate_variance = np.var(hrinfo.loc[:,'DailyRate'])
print ("Mean is : ",dailyrate_mean)
print ("Median is : ",dailyrate_median)
print ("Variance is : ",dailyrate_variance)
# Out:
# Mean is :  802.4857142857143
# Median is :  802.0
# Variance is :  162708.83210884358

# %% [markdown]
# ### Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)

# %%
sns.boxplot(x="Attrition", y="PercentSalaryHike", data=hrinfo)

# %% [markdown]
# ### Plot Total working years using matplotlib plot function

# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(51,30))
plt.plot('YearsAtCompany',data=hrinfo,linewidth=2)

plt.title("Total Working Years")
plt.show()
